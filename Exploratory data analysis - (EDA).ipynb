# %%
# Install the required package from Pypi
# !pip install pca
# Out:
# Collecting pca
#   Using cached pca-2.10.0-py3-none-any.whl.metadata (12 kB)
# Collecting datazets (from pca)
#   Using cached datazets-1.1.3-py3-none-any.whl.metadata (13 kB)
# Collecting statsmodels (from pca)
#   Downloading statsmodels-0.14.5-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: matplotlib in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from pca) (3.10.6)
# Requirement already satisfied: numpy in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from pca) (2.3.3)
# Collecting scikit-learn (from pca)
#   Downloading scikit_learn-1.7.2-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: scipy in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from pca) (1.16.2)
# Collecting colourmap>=1.1.19 (from pca)
#   Using cached colourmap-1.2.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from pca) (2.3.3)
# Collecting scatterd>=1.3.7 (from pca)
#   Using cached scatterd-1.4.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting adjusttext (from pca)
#   Using cached adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: seaborn in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from scatterd>=1.3.7->pca) (0.13.2)
# Collecting requests (from datazets->pca)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pca) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pca) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pca) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pca) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pca) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pca) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pca) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->pca) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib->pca) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from pandas->pca) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sakshi kumari\appdata\local\programs\python\python313\lib\site-packages (from pandas->pca) (2025.2)
# Collecting charset_normalizer<4,>=2 (from requests->datazets->pca)
#   Downloading charset_normalizer-3.4.3-cp313-cp313-win_amd64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->datazets->pca)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->datazets->pca)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->datazets->pca)
#   Using cached certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->pca)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->pca)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting patsy>=0.5.6 (from statsmodels->pca)
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Using cached pca-2.10.0-py3-none-any.whl (34 kB)
# Using cached colourmap-1.2.0-py3-none-any.whl (11 kB)
# Using cached scatterd-1.4.1-py3-none-any.whl (13 kB)
# Using cached adjustText-1.3.0-py3-none-any.whl (13 kB)
# Using cached datazets-1.1.3-py3-none-any.whl (190 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.3-cp313-cp313-win_amd64.whl (107 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading scikit_learn-1.7.2-cp313-cp313-win_amd64.whl (8.7 MB)
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.7 MB 313.5 kB/s eta 0:00:27
#    -- ------------------------------------- 0.5/8.7 MB 313.5 kB/s eta 0:00:27
#    -- ------------------------------------- 0.5/8.7 MB 313.5 kB/s eta 0:00:27
#    -- ------------------------------------- 0.5/8.7 MB 313.5 kB/s eta 0:00:27
#    --- ------------------------------------ 0.8/8.7 MB 336.9 kB/s eta 0:00:24
#    --- ------------------------------------ 0.8/8.7 MB 336.9 kB/s eta 0:00:24
#    ---- ----------------------------------- 1.0/8.7 MB 380.4 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.0/8.7 MB 380.4 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.0/8.7 MB 380.4 kB/s eta 0:00:21
#    ---- ----------------------------------- 1.0/8.7 MB 380.4 kB/s eta 0:00:21
#    ------ --------------------------------- 1.3/8.7 MB 357.4 kB/s eta 0:00:21
#    ------ --------------------------------- 1.3/8.7 MB 357.4 kB/s eta 0:00:21
#    ------ --------------------------------- 1.3/8.7 MB 357.4 kB/s eta 0:00:21
#    ------ --------------------------------- 1.3/8.7 MB 357.4 kB/s eta 0:00:21
#    ------ --------------------------------- 1.3/8.7 MB 357.4 kB/s eta 0:00:21
#    ------ --------------------------------- 1.3/8.7 MB 357.4 kB/s eta 0:00:21
#    ------ --------------------------------- 1.3/8.7 MB 357.4 kB/s eta 0:00:21
#    ------- -------------------------------- 1.6/8.7 MB 302.7 kB/s eta 0:00:24
#    ------- -------------------------------- 1.6/8.7 MB 302.7 kB/s eta 0:00:24
#    -------- ------------------------------- 1.8/8.7 MB 338.3 kB/s eta 0:00:21
#    --------- ------------------------------ 2.1/8.7 MB 369.6 kB/s eta 0:00:18
#    --------- ------------------------------ 2.1/8.7 MB 369.6 kB/s eta 0:00:18
#    ---------- ----------------------------- 2.4/8.7 MB 397.3 kB/s eta 0:00:16
#    ---------- ----------------------------- 2.4/8.7 MB 397.3 kB/s eta 0:00:16
#    ------------ --------------------------- 2.6/8.7 MB 414.8 kB/s eta 0:00:15
#    ------------- -------------------------- 2.9/8.7 MB 434.9 kB/s eta 0:00:14
#    ------------- -------------------------- 2.9/8.7 MB 434.9 kB/s eta 0:00:14
#    -------------- ------------------------- 3.1/8.7 MB 452.4 kB/s eta 0:00:13
#    --------------- ------------------------ 3.4/8.7 MB 475.4 kB/s eta 0:00:12
#    ---------------- ----------------------- 3.7/8.7 MB 492.9 kB/s eta 0:00:11
#    ---------------- ----------------------- 3.7/8.7 MB 492.9 kB/s eta 0:00:11
#    ------------------ --------------------- 3.9/8.7 MB 504.0 kB/s eta 0:00:10
#    ------------------- -------------------- 4.2/8.7 MB 525.1 kB/s eta 0:00:09
#    -------------------- ------------------- 4.5/8.7 MB 542.6 kB/s eta 0:00:08
#    -------------------- ------------------- 4.5/8.7 MB 542.6 kB/s eta 0:00:08
#    --------------------- ------------------ 4.7/8.7 MB 559.1 kB/s eta 0:00:08
#    ---------------------- ----------------- 5.0/8.7 MB 576.9 kB/s eta 0:00:07
#    ------------------------ --------------- 5.2/8.7 MB 593.7 kB/s eta 0:00:06
#    ------------------------- -------------- 5.5/8.7 MB 606.5 kB/s eta 0:00:06
#    -------------------------- ------------- 5.8/8.7 MB 617.1 kB/s eta 0:00:05
#    --------------------------- ------------ 6.0/8.7 MB 628.4 kB/s eta 0:00:05
#    ---------------------------- ----------- 6.3/8.7 MB 646.4 kB/s eta 0:00:04
#    ------------------------------ --------- 6.6/8.7 MB 653.1 kB/s eta 0:00:04
#    ------------------------------ --------- 6.6/8.7 MB 653.1 kB/s eta 0:00:04
#    ------------------------------- -------- 6.8/8.7 MB 660.1 kB/s eta 0:00:03
#    --------------------------------- ------ 7.3/8.7 MB 691.9 kB/s eta 0:00:02
#    ---------------------------------- ----- 7.6/8.7 MB 708.6 kB/s eta 0:00:02
#    ------------------------------------- -- 8.1/8.7 MB 737.8 kB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 753.5 kB/s eta 0:00:01
#    ---------------------------------------  8.7/8.7 MB 757.3 kB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 757.1 kB/s  0:00:11
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading statsmodels-0.14.5-cp313-cp313-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 1.5 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.6 MB 1.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.6 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.6 MB 1.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.6 MB 1.2 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.6 MB 1.2 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.6 MB 1.2 MB/s eta 0:00:07
#    --------- ------------------------------ 2.4/9.6 MB 1.2 MB/s eta 0:00:06
#    ------------ --------------------------- 2.9/9.6 MB 1.4 MB/s eta 0:00:05
#    ------------- -------------------------- 3.1/9.6 MB 1.4 MB/s eta 0:00:05
#    -------------- ------------------------- 3.4/9.6 MB 1.4 MB/s eta 0:00:05
#    --------------- ------------------------ 3.7/9.6 MB 1.4 MB/s eta 0:00:05
#    ---------------- ----------------------- 3.9/9.6 MB 1.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.6 MB 1.3 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.6 MB 1.3 MB/s eta 0:00:04
#    -------------------- ------------------- 5.0/9.6 MB 1.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.5/9.6 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 6.0/9.6 MB 1.5 MB/s eta 0:00:03
#    --------------------------- ------------ 6.6/9.6 MB 1.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.1/9.6 MB 1.6 MB/s eta 0:00:02
#    ------------------------------ --------- 7.3/9.6 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 7.9/9.6 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 8.1/9.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.6 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 1.5 MB/s  0:00:06
# Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: urllib3, threadpoolctl, patsy, joblib, idna, charset_normalizer, certifi, scikit-learn, requests, statsmodels, datazets, colourmap, adjusttext, scatterd, pca
#
#    ----------------------------------------  0/15 [urllib3]
#    ----------------------------------------  0/15 [urllib3]
#    ----------------------------------------  0/15 [urllib3]
#    ----------------------------------------  0/15 [urllib3]
#    ----------------------------------------  0/15 [urllib3]
#    -- -------------------------------------  1/15 [threadpoolctl]
#    ----- ----------------------------------  2/15 [patsy]
#    ----- ----------------------------------  2/15 [patsy]
#    ----- ----------------------------------  2/15 [patsy]
#    ----- ----------------------------------  2/15 [patsy]
#    ----- ----------------------------------  2/15 [patsy]
#    -------- -------------------------------  3/15 [joblib]
#    -------- -------------------------------  3/15 [joblib]
#    -------- -------------------------------  3/15 [joblib]
#    -------- -------------------------------  3/15 [joblib]
#    -------- -------------------------------  3/15 [joblib]
#    -------- -------------------------------  3/15 [joblib]
#    -------- -------------------------------  3/15 [joblib]
#    -------- -------------------------------  3/15 [joblib]
#    -------- -------------------------------  3/15 [joblib]
#    -------- -------------------------------  3/15 [joblib]
#    -------- -------------------------------  3/15 [joblib]
#    ---------- -----------------------------  4/15 [idna]
#    ---------- -----------------------------  4/15 [idna]
#    ------------- --------------------------  5/15 [charset_normalizer]
#    ------------- --------------------------  5/15 [charset_normalizer]
#    ------------- --------------------------  5/15 [charset_normalizer]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    ------------------ ---------------------  7/15 [scikit-learn]
#    --------------------- ------------------  8/15 [requests]
#    --------------------- ------------------  8/15 [requests]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ------------------------ ---------------  9/15 [statsmodels]
#    ----------------------------- ---------- 11/15 [colourmap]
#    ---------------------------------- ----- 13/15 [scatterd]
#    ---------------------------------------- 15/15 [pca]
#
# Successfully installed adjusttext-1.3.0 certifi-2025.8.3 charset_normalizer-3.4.3 colourmap-1.2.0 datazets-1.1.3 idna-3.10 joblib-1.5.2 patsy-1.0.1 pca-2.10.0 requests-2.32.5 scatterd-1.4.1 scikit-learn-1.7.2 statsmodels-0.14.5 threadpoolctl-3.6.0 urllib3-2.5.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
life_exep_data = pd.read_csv('data/impv/final.csv')

# %%
life_exep_data.head()
# Out:
#        Country  Year  Gender  Life expectancy  Unemployment  Infant Mortality  \
# 0  Afghanistan  2000  Female           57.120        13.846            85.000
# 1  Afghanistan  2001  Female           57.596        13.849            82.700
# 2  Afghanistan  2002  Female           58.080        14.355            80.400
# 3  Afghanistan  2003  Female           58.578        14.222            77.800
# 4  Afghanistan  2004  Female           59.093        14.047            75.300
#
#               GDP             GNI  Clean fuels and cooking technologies  \
# 0 13684491660.790 18240442244.769                                 6.400
# 1 13684491660.790 18240442244.769                                 7.200
# 2  4055179566.350 18240442244.769                                 8.200
# 3  4515558808.110 18240442244.769                                 9.400
# 4  5226778808.892 18240442244.769                                10.400
#
#    Per Capita  ...  DPT Immunization  HepB3 Immunization  \
# 0     434.740  ...            24.000              65.077
# 1     434.740  ...            33.000              65.077
# 2     179.427  ...            36.000              65.077
# 3     190.684  ...            41.000              65.077
# 4     211.382  ...            50.000              65.077
#
#    Measles Immunization  Hospital beds  Basic sanitation services  \
# 0                27.000          0.300                     21.871
# 1                37.000          0.390                     21.881
# 2                35.000          0.390                     23.274
# 3                39.000          0.390                     24.667
# 4                48.000          0.390                     26.068
#
#    Tuberculosis treatment  Urban population  Rural population  \
# 0                  85.000            22.078            77.922
# 1                  84.000            22.169            77.831
# 2                  87.000            22.261            77.739
# 3                  86.000            22.353            77.647
# 4                  89.000            22.500            77.500
#
#    Non-communicable Mortality  Sucide Rate
# 0                      39.400        4.800
# 1                      40.100        4.800
# 2                      40.500        4.600
# 3                      40.100        4.600
# 4                      40.200        4.600
#
# [5 rows x 22 columns]

# %%
life_exep_data.describe()
# Out:
#           Year  Life expectancy  Unemployment  Infant Mortality  \
# count 9928.000         9928.000      9928.000          9928.000
# mean  2009.495           69.834         8.256            30.235
# std      5.762            9.302         6.155            25.461
# min   2000.000           38.861         0.052             1.400
# 25%   2005.000           63.894         4.331             9.300
# 50%   2009.000           71.445         6.561            23.300
# 75%   2014.000           76.845        10.133            44.865
# max   2019.000           88.100        43.166           146.200
#
#                      GDP                GNI  \
# count           9928.000           9928.000
# mean   2032870320199.633  2042053577025.780
# std    7249369673698.859  7254721460142.502
# min         63101272.370       72802185.001
# 25%       7267552276.129     7584112233.046
# 50%      45247974037.038    45940355554.258
# 75%     501278724553.924   523061711019.377
# max   87568054407493.094 87532722519257.594
#
#        Clean fuels and cooking technologies  Per Capita  \
# count                              9928.000    9928.000
# mean                                 60.593   12668.853
# std                                  36.964   19447.598
# min                                   0.000     111.927
# 25%                                  23.000    1366.059
# 50%                                  61.950    4348.605
# 75%                                  99.334   14443.944
# max                                 100.000  180366.715
#
#        Mortality caused by road traffic injury  Tuberculosis Incidence  \
# count                                 9928.000                9928.000
# mean                                    18.229                 136.043
# std                                      8.223                 176.090
# min                                      0.000                   0.000
# 25%                                     12.700                  21.000
# 50%                                     18.229                  82.000
# 75%                                     24.100                 159.000
# max                                     64.600                1590.000
#
#        DPT Immunization  HepB3 Immunization  Measles Immunization  \
# count          9928.000            9928.000              9928.000
# mean             85.685              81.308                84.855
# std              14.208              18.469                14.218
# min              19.000               0.050                16.000
# 25%              81.000              75.083                79.000
# 50%              90.104              86.700                89.320
# 75%              96.000              95.000                95.092
# max              99.000              99.000                99.000
#
#        Hospital beds  Basic sanitation services  Tuberculosis treatment  \
# count       9928.000                   9928.000                9928.000
# mean           2.986                     71.106                  76.726
# std            2.284                     29.583                  14.757
# min            0.010                      2.755                   0.000
# 25%            1.308                     46.007                  73.000
# 50%            2.632                     84.227                  78.000
# 75%            3.600                     97.177                  86.000
# max           14.690                    100.000                 100.000
#
#        Urban population  Rural population  Non-communicable Mortality  \
# count          9928.000          9928.000                    9928.000
# mean             55.559            44.441                      22.100
# std              22.436            22.436                       8.504
# min               8.246             0.000                       4.400
# 25%              36.519            26.118                      16.300
# 50%              55.367            44.633                      21.925
# 75%              73.882            63.481                      26.200
# max             100.000            91.754                      64.100
#
#        Sucide Rate
# count     9928.000
# mean        10.619
# std         11.070
# min          0.000
# 25%          4.000
# 50%          7.800
# 75%         12.300
# max        147.800

# %%
# life_exep_data['Gender'] = life_exep_data['Gender'].map({'Male': 0,'Female': 1})

# %%
life_exep_data.skew(axis = 0, numeric_only = True)
# Out:
# Year                                      -0.001
# Life expectancy                           -0.617
# Unemployment                               1.768
# Infant Mortality                           1.089
# GDP                                        5.889
# GNI                                        5.910
# Clean fuels and cooking technologies      -0.383
# Per Capita                                 2.994
# Mortality caused by road traffic injury    0.213
# Tuberculosis Incidence                     3.097
# DPT Immunization                          -1.661
# HepB3 Immunization                        -1.792
# Measles Immunization                      -1.434
# Hospital beds                              1.668
# Basic sanitation services                 -0.759
# Tuberculosis treatment                    -2.230
# Urban population                           0.067
# Rural population                          -0.067
# Non-communicable Mortality                 0.880
# Sucide Rate                                3.686
# dtype: float64

# %% [markdown]
# Lets visualise the distribution of Life Expectancy at birth.

# %%
def plot_histogram(data, ylabel, xlabel, title):
    plt.figure(figsize = (10, 6))
    plt.hist(data, edgecolor="white")
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title);

# %%
def get_outlier(df, column):
    Q1 = np.percentile(df[column], 25, interpolation = 'midpoint')
    Q3 = np.percentile(df[column], 75, interpolation = 'midpoint')
    IQR = Q3 - Q1
    return df[(df[column]>=(Q3+1.5*IQR)) | (df[column]<=(Q1-1.5*IQR))].sort_values(by=[column]).reset_index()

# %%
plot_histogram(life_exep_data['Life expectancy'], 'Count', 'Life Expectancy at Birth', "Histogram of Life Expectancy at Birth")

# %%
life_exep_data['Life expectancy'].skew()
# Out:
# -0.617472379194249

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Life expectancy'])
# Out:
# <Axes: xlabel='Life expectancy'>

# %% [markdown]
# From the above histogram we can conclude that most of data lies between 70 and 80.
#
# Next we are going to do visualise the distribution of Unemployment column.

# %%
df = get_outlier(life_exep_data, 'Life expectancy')

df[['Country','Year','Gender','Life expectancy']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\4132502382.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Life expectancy')
#                      Country  Year  Gender  Life expectancy
# 0               Sierra Leone  2000    Male           38.861
# 1               Sierra Leone  2001    Male           39.745
# 2               Sierra Leone  2000  Female           40.005
# 3                    Lesotho  2006    Male           40.418
# 4                    Lesotho  2007    Male           40.555
# 5                    Lesotho  2005    Male           40.566
# 6                   Eswatini  2005    Male           40.663
# 7               Sierra Leone  2002    Male           40.708
# 8                   Eswatini  2004    Male           40.749
# 9                   Eswatini  2006    Male           40.923
# 10                   Lesotho  2008    Male           40.950
# 11              Sierra Leone  2001  Female           40.976
# 12                   Lesotho  2004    Male           41.012
# 13                  Eswatini  2003    Male           41.189
# 14                  Zimbabwe  2004    Male           41.366
# 15                  Zimbabwe  2003    Male           41.442
# 16                  Eswatini  2007    Male           41.473
# 17                  Zimbabwe  2005    Male           41.573
# 18                   Lesotho  2009    Male           41.579
# 19                  Zimbabwe  2002    Male           41.695
# 20              Sierra Leone  2003    Male           41.712
# 21                   Lesotho  2003    Male           41.717
# 22                    Zambia  2000    Male           41.927
# 23                  Eswatini  2002    Male           41.972
# 24              Sierra Leone  2002  Female           42.023
# 25                  Zimbabwe  2001    Male           42.086
# 26                  Zimbabwe  2006    Male           42.193
# 27                  Eswatini  2008    Male           42.255
# 28                   Lesotho  2010    Male           42.412
# 29                    Zambia  2001    Male           42.542
# 30                  Zimbabwe  2000    Male           42.609
# 31                   Lesotho  2002    Male           42.631
# 32  Central African Republic  2001    Male           42.704
# 33              Sierra Leone  2004    Male           42.726
# 34  Central African Republic  2000    Male           42.727
# 35  Central African Republic  2002    Male           42.787
# 36                    Malawi  2000    Male           42.836
# 37  Central African Republic  2003    Male           42.953
# 38                    Malawi  2001    Male           42.973
# 39                  Eswatini  2001    Male           43.078
# 40              Sierra Leone  2003  Female           43.103
# 41  Central African Republic  2004    Male           43.193
# 42                  Eswatini  2009    Male           43.227
# 43                  Zimbabwe  2007    Male           43.276
# 44                    Malawi  2002    Male           43.289
# 45                    Uganda  2000    Male           43.323
# 46                    Zambia  2002    Male           43.331
# 47                   Lesotho  2011    Male           43.417
# 48  Central African Republic  2005    Male           43.500
# 49                   Lesotho  2001    Male           43.712
# 50              Sierra Leone  2005    Male           43.731
# 51                    Malawi  2003    Male           43.807
# 52  Central African Republic  2006    Male           43.868
# 53              Sierra Leone  2004  Female           44.184
# 54                    Zambia  2003    Male           44.249
# 55  Central African Republic  2007    Male           44.291
# 56                  Eswatini  2010    Male           44.369
# 57                    Uganda  2001    Male           44.424

# %%
plot_histogram(life_exep_data['Unemployment'], 'Count', 'Unemployment', "Histogram of unemployment")

# %% [markdown]
# From the above histogram we can conclude most of the data are between 5 to 10.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Unemployment'])
# Out:
# <Axes: xlabel='Unemployment'>

# %%
df = get_outlier(life_exep_data, 'Unemployment')

df[['Country','Year','Gender','Unemployment']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\4049387310.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Unemployment')
#                     Country  Year  Gender  Unemployment
# 0                  Bulgaria  2001  Female        18.855
# 1    Bosnia and Herzegovina  2017    Male        18.857
# 2                    Poland  2003    Male        18.898
# 3                 St. Lucia  2015    Male        18.905
# 4               Congo, Rep.  2012    Male        18.911
# ..                      ...   ...     ...           ...
# 753            South Africa  2002  Female        41.372
# 754      West Bank and Gaza  2018  Female        41.873
# 755                 Lesotho  2001  Female        41.936
# 756      West Bank and Gaza  2017  Female        42.811
# 757                 Lesotho  2000  Female        43.166
#
# [758 rows x 4 columns]

# %%
plot_histogram(life_exep_data['Infant Mortality'], 'Count', 'Infant Mortality', "Histogram of Infant Mortality")

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Infant Mortality'])
# Out:
# <Axes: xlabel='Infant Mortality'>

# %%
df = get_outlier(life_exep_data, 'Infant Mortality')

df[['Country','Year','Gender','Infant Mortality']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\3203116214.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Infant Mortality')
#                                         Country  Year  Gender  \
# 0                                       Liberia  2005    Male
# 1                                          Chad  2006    Male
# 2                             Equatorial Guinea  2000  Female
# 3     Sub-Saharan Africa (IDA & IBRD countries)  2000    Male
# 4    Sub-Saharan Africa (excluding high income)  2000    Male
# ..                                          ...   ...     ...
# 148                                Sierra Leone  2003    Male
# 149                                     Liberia  2000    Male
# 150                                Sierra Leone  2002    Male
# 151                                Sierra Leone  2001    Male
# 152                                Sierra Leone  2000    Male
#
#      Infant Mortality
# 0              98.500
# 1              98.500
# 2              98.500
# 3              98.551
# 4              98.556
# ..                ...
# 148           137.700
# 149           137.800
# 150           140.700
# 151           143.400
# 152           146.200
#
# [153 rows x 4 columns]

# %%
plot_histogram(life_exep_data['GDP'], 'Count', 'GDP', "Histogram of GDP")

# %% [markdown]
# From the above histogram we can conclude that the data has left skewed.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['GDP'])
# Out:
# <Axes: xlabel='GDP'>

# %%
life_exep_data['GDP'].skew()
# Out:
# 5.889286292623093

# %%
df = get_outlier(life_exep_data, 'GDP')

df[['Country','Year','Gender','GDP']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\1464237408.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'GDP')
#                                            Country  Year  Gender  \
# 0                                      Korea, Rep.  2011  Female
# 1                                      Korea, Rep.  2011    Male
# 2     Europe & Central Asia (IDA & IBRD countries)  2003  Female
# 3     Europe & Central Asia (IDA & IBRD countries)  2003    Male
# 4                         Pre-demographic dividend  2017  Female
# ...                                            ...   ...     ...
# 1775                                         World  2017  Female
# 1776                                         World  2018    Male
# 1777                                         World  2018  Female
# 1778                                         World  2019  Female
# 1779                                         World  2019    Male
#
#                     GDP
# 0     1253223044718.990
# 1     1253223044718.990
# 2     1257924182661.530
# 3     1257924182661.530
# 4     1258665620177.510
# ...                 ...
# 1775 81193291658568.797
# 1776 86267600625419.406
# 1777 86267600625419.406
# 1778 87568054407493.094
# 1779 87568054407493.094
#
# [1780 rows x 4 columns]

# %%
outlier_countries = df['Country'].unique()
remove_list = ["Korea, Rep.", "Spain", "Mexico", "Italy", "Russian Federation", "Canada", "Australia", "China", "India", "France", "Brazil", "United Kingdom", "Germany", "St. Martin (French part)", "Korea, Dem. People's Rep.", "Japan", "United States"]
remove_list = np.setdiff1d(outlier_countries,remove_list)

# %%
life_exep_data[life_exep_data.Country.isin(remove_list)]
# Out:
#          Country  Year  Gender  Life expectancy  Unemployment  \
# 140   Arab World  2000  Female           69.700        17.881
# 141   Arab World  2001  Female           69.960        17.757
# 142   Arab World  2002  Female           70.219        18.241
# 143   Arab World  2003  Female           70.484        18.103
# 144   Arab World  2004  Female           70.758        17.906
# ...          ...   ...     ...              ...           ...
# 9863       World  2015    Male           69.784         5.493
# 9864       World  2016    Male           70.014         5.522
# 9865       World  2017    Male           70.227         5.423
# 9866       World  2018    Male           70.409         5.283
# 9867       World  2019    Male           70.585         5.258
#
#       Infant Mortality                GDP                GNI  \
# 140             40.375   816038849805.683   796768261498.565
# 141             39.166   798525022054.761   784098282162.029
# 142             37.948   803142348125.716   792448918283.542
# 143             36.858   887874177404.300   873535008967.277
# 144             35.733  1056272163163.200  1044492857776.080
# ...                ...                ...                ...
# 9863            33.500 75112444159420.094 75232602112653.594
# 9864            32.600 76305058874647.797 76282280462949.000
# 9865            31.700 81193291658568.797 81295071732629.797
# 9866            30.900 86267600625419.406 86243803476022.203
# 9867            30.200 87568054407493.094 87532722519257.594
#
#       Clean fuels and cooking technologies  Per Capita  ...  DPT Immunization  \
# 140                                 75.328    2890.228  ...            82.937
# 141                                 76.636    2768.502  ...            84.083
# 142                                 77.881    2725.610  ...            82.017
# 143                                 79.027    2948.633  ...            82.386
# 144                                 80.002    3430.983  ...            83.301
# ...                                    ...         ...  ...               ...
# 9863                                61.621   10222.608  ...            84.785
# 9864                                62.746   10264.929  ...            85.842
# 9865                                63.802   10798.153  ...            85.795
# 9866                                65.063   11347.336  ...            85.617
# 9867                                66.178   11397.086  ...            85.691
#
#       HepB3 Immunization  Measles Immunization  Hospital beds  \
# 140               55.255                81.453          1.599
# 141               59.460                81.010          1.643
# 142               59.965                81.158          1.576
# 143               60.288                81.400          1.571
# 144               66.780                82.045          1.606
# ...                  ...                   ...            ...
# 9863              82.717                84.949          2.706
# 9864              84.018                85.204          2.759
# 9865              83.650                85.257          2.894
# 9866              83.468                85.648          2.736
# 9867              84.951                85.696          2.736
#
#       Basic sanitation services  Tuberculosis treatment  Urban population  \
# 140                      73.305                  76.726            52.989
# 141                      73.568                  76.726            53.251
# 142                      74.163                  76.726            53.516
# 143                      74.547                  76.726            53.801
# 144                      74.959                  76.726            54.106
# ...                         ...                     ...               ...
# 9863                     72.764                  83.000            53.916
# 9864                     73.904                  81.000            54.374
# 9865                     74.930                  85.000            54.828
# 9866                     76.034                  85.000            55.277
# 9867                     77.017                  86.000            55.720
#
#       Rural population  Non-communicable Mortality  Sucide Rate
# 140             47.011                      22.326        3.240
# 141             46.749                      22.457        3.189
# 142             46.484                      22.451        3.137
# 143             46.199                      22.314        3.066
# 144             45.894                      22.108        3.018
# ...                ...                         ...          ...
# 9863            46.084                      22.725       13.028
# 9864            45.626                      22.607       12.860
# 9865            45.172                      22.197       12.775
# 9866            44.723                      21.947       12.756
# 9867            44.280                      21.736       12.577
#
# [1480 rows x 22 columns]

# %%
life_exep_data = life_exep_data[~life_exep_data.Country.isin(remove_list)]

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['GDP'])
# Out:
# <Axes: xlabel='GDP'>

# %%
df = get_outlier(life_exep_data, 'GDP')

df[['Country','Year','Gender','GDP']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\1464237408.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'GDP')
#                          Country  Year  Gender                GDP
# 0                   South Africa  2011    Male   458201514136.977
# 1                   South Africa  2011  Female   458201514136.977
# 2             Iran, Islamic Rep.  2013    Male   460293149324.326
# 3             Iran, Islamic Rep.  2013  Female   460293149324.326
# 4     Africa Western and Central  2007  Female   461777599573.788
# ...                          ...   ...     ...                ...
# 1103               United States  2017    Male 19542979183000.000
# 1104               United States  2018  Female 20611860934000.000
# 1105               United States  2018    Male 20611860934000.000
# 1106               United States  2019  Female 21433224697000.000
# 1107               United States  2019    Male 21433224697000.000
#
# [1108 rows x 4 columns]

# %%
plot_histogram(life_exep_data['GDP'], 'Count', 'GDP', "Histogram of GDP")

# %%
life_exep_data['GDP'] = np.log(life_exep_data['GDP'])

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['GDP'])
# Out:
# <Axes: xlabel='GDP'>

# %%
life_exep_data[(life_exep_data['Year']==2019)]['GDP'].mean()
# Out:
# 24.599324597087456

# %%
sub = life_exep_data[life_exep_data['Country'] == 'United States']
sub[['Country','Year','Gender','GDP', 'GNI']]
# Out:
#             Country  Year  Gender    GDP                GNI
# 4704  United States  2000  Female 29.959 10383667000000.000
# 4705  United States  2001  Female 29.990 10746067000000.000
# 4706  United States  2002  Female 30.023 11052223000000.000
# 4707  United States  2003  Female 30.070 11534846000000.000
# 4708  United States  2004  Female 30.134 12317643000000.000
# 4709  United States  2005  Female 30.199 13166516000000.000
# 4710  United States  2006  Female 30.257 14066382000000.000
# 4711  United States  2007  Female 30.302 14550103000000.000
# 4712  United States  2008  Female 30.320 14718111000000.000
# 4713  United States  2009  Female 30.302 14426269000000.000
# 4714  United States  2010  Female 30.339 15172073000000.000
# 4715  United States  2011  Female 30.375 15849978000000.000
# 4716  United States  2012  Female 30.416 16675595000000.000
# 4717  United States  2013  Female 30.451 17188331000000.000
# 4718  United States  2014  Female 30.495 18043094000000.000
# 4719  United States  2015  Female 30.535 18660910000000.000
# 4720  United States  2016  Female 30.562 19020479000000.000
# 4721  United States  2017  Female 30.604 19893073000000.000
# 4722  United States  2018  Female 30.657 20946778000000.000
# 4723  United States  2019  Female 30.696 21708650000000.000
# 9668  United States  2000    Male 29.959 10383667000000.000
# 9669  United States  2001    Male 29.990 10746067000000.000
# 9670  United States  2002    Male 30.023 11052223000000.000
# 9671  United States  2003    Male 30.070 11534846000000.000
# 9672  United States  2004    Male 30.134 12317643000000.000
# 9673  United States  2005    Male 30.199 13166516000000.000
# 9674  United States  2006    Male 30.257 14066382000000.000
# 9675  United States  2007    Male 30.302 14550103000000.000
# 9676  United States  2008    Male 30.320 14718111000000.000
# 9677  United States  2009    Male 30.302 14426269000000.000
# 9678  United States  2010    Male 30.339 15172073000000.000
# 9679  United States  2011    Male 30.375 15849978000000.000
# 9680  United States  2012    Male 30.416 16675595000000.000
# 9681  United States  2013    Male 30.451 17188331000000.000
# 9682  United States  2014    Male 30.495 18043094000000.000
# 9683  United States  2015    Male 30.535 18660910000000.000
# 9684  United States  2016    Male 30.562 19020479000000.000
# 9685  United States  2017    Male 30.604 19893073000000.000
# 9686  United States  2018    Male 30.657 20946778000000.000
# 9687  United States  2019    Male 30.696 21708650000000.000

# %%
plot_histogram(life_exep_data['GNI'], 'Count', 'GNI', "Histogram of GNI")

# %% [markdown]
# From the above histogram we can conclude that the data has left skewed.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['GNI'])
# Out:
# <Axes: xlabel='GNI'>

# %%
df = get_outlier(life_exep_data, 'GNI')

df[['Country','Year','Gender','GNI']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\610805785.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'GNI')
#                                            Country  Year  Gender  \
# 0                                      Switzerland  2006    Male
# 1                                      Switzerland  2006  Female
# 2     Least developed countries: UN classification  2007  Female
# 3     Least developed countries: UN classification  2007    Male
# 4                                          Belgium  2007    Male
# ...                                            ...   ...     ...
# 1149                                 United States  2017    Male
# 1150                                 United States  2018  Female
# 1151                                 United States  2018    Male
# 1152                                 United States  2019    Male
# 1153                                 United States  2019  Female
#
#                     GNI
# 0      475184149784.655
# 1      475184149784.655
# 2      475315446516.675
# 3      475315446516.675
# 4      476866548042.705
# ...                 ...
# 1149 19893073000000.000
# 1150 20946778000000.000
# 1151 20946778000000.000
# 1152 21708650000000.000
# 1153 21708650000000.000
#
# [1154 rows x 4 columns]

# %%
life_exep_data['GNI'] = np.log(life_exep_data['GNI'])

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['GNI'])
# Out:
# <Axes: xlabel='GNI'>

# %%
plot_histogram(life_exep_data['Clean fuels and cooking technologies'], 'Count', 'Clean fuels and cooking technologies', "Histogram of Clean fuels and cooking technologies")

# %% [markdown]
# From the above histogram we can find that most of the data lies between 90 and 100.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Clean fuels and cooking technologies'])
# Out:
# <Axes: xlabel='Clean fuels and cooking technologies'>

# %%
df = get_outlier(life_exep_data, 'Clean fuels and cooking technologies')
df[['Country','Year','Gender','Clean fuels and cooking technologies']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\3901714231.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Clean fuels and cooking technologies')
# Empty DataFrame
# Columns: [Country, Year, Gender, Clean fuels and cooking technologies]
# Index: []

# %%
plot_histogram(life_exep_data['Per Capita'], 'Count', 'Per Capita', "Histogram of Per Capita")

# %% [markdown]
# Per Capita income has distribution of left skewed.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Per Capita'])
# Out:
# <Axes: xlabel='Per Capita'>

# %%
df = get_outlier(life_exep_data, 'Per Capita')
df[['Country','Year','Gender','Per Capita']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\3364192916.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Per Capita')
#            Country  Year  Gender  Per Capita
# 0    New Caledonia  2008    Male   37353.737
# 1    New Caledonia  2008  Female   37353.737
# 2    New Caledonia  2010    Male   37494.895
# 3    New Caledonia  2010  Female   37494.895
# 4           Kuwait  2009    Male   37561.726
# ..             ...   ...     ...         ...
# 955  Liechtenstein  2019  Female  175813.876
# 956  Liechtenstein  2014    Male  178864.852
# 957  Liechtenstein  2014  Female  178864.852
# 958  Liechtenstein  2018  Female  180366.715
# 959  Liechtenstein  2018    Male  180366.715
#
# [960 rows x 4 columns]

# %%
plot_histogram(life_exep_data['Mortality caused by road traffic injury'], 'Count', 'Mortality caused by road traffic injury', "Histogram of Mortality caused by road traffic injury")

# %% [markdown]
# The above histogram shows that the data are normaly distributed.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Mortality caused by road traffic injury'])
# Out:
# <Axes: xlabel='Mortality caused by road traffic injury'>

# %%
df = get_outlier(life_exep_data, 'Mortality caused by road traffic injury')
df[['Country','Year','Gender','Mortality caused by road traffic injury']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\535447701.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Mortality caused by road traffic injury')
#               Country  Year  Gender  Mortality caused by road traffic injury
# 0        South Africa  2003  Female                                   43.400
# 1        South Africa  2003    Male                                   43.400
# 2        South Africa  2000  Female                                   44.000
# 3        South Africa  2000    Male                                   44.000
# 4  Dominican Republic  2017  Female                                   46.300
# 5  Dominican Republic  2017    Male                                   46.300
# 6  Dominican Republic  2018  Female                                   53.500
# 7  Dominican Republic  2018    Male                                   53.500
# 8  Dominican Republic  2019  Female                                   64.600
# 9  Dominican Republic  2019    Male                                   64.600

# %%
plot_histogram(life_exep_data['Tuberculosis Incidence'], 'Count', 'Tuberculosis Incidence', "Histogram of Tuberculosis Incidence")

# %% [markdown]
# Tuberculosis Incidence has distribution of left skewed.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Tuberculosis Incidence'])
# Out:
# <Axes: xlabel='Tuberculosis Incidence'>

# %%
df = get_outlier(life_exep_data, 'Tuberculosis Incidence')
df[['Country','Year','Gender','Tuberculosis Incidence']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\3872018586.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Tuberculosis Incidence')
#       Country  Year  Gender  Tuberculosis Incidence
# 0       Nepal  2001    Male                 405.000
# 1       Nepal  2001  Female                 405.000
# 2      Zambia  2014    Male                 406.000
# 3      Zambia  2014  Female                 406.000
# 4    Kiribati  2012    Male                 407.000
# ..        ...   ...     ...                     ...
# 693  Eswatini  2006  Female                1460.000
# 694  Eswatini  2010    Male                1590.000
# 695  Eswatini  2010  Female                1590.000
# 696  Eswatini  2009  Female                1590.000
# 697  Eswatini  2009    Male                1590.000
#
# [698 rows x 4 columns]

# %%
plot_histogram(life_exep_data['DPT Immunization'], 'Count', 'DPT Immunization', "Histogram of DPT Immunization")

# %% [markdown]
# The data of DPT Immunization is skewed towards right.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['DPT Immunization'])
# Out:
# <Axes: xlabel='DPT Immunization'>

# %%
df = get_outlier(life_exep_data, 'DPT Immunization')
df[['Country','Year','Gender','DPT Immunization']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\1709384012.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'DPT Immunization')
#          Country  Year  Gender  DPT Immunization
# 0        Ukraine  2016  Female            19.000
# 1           Chad  2008  Female            19.000
# 2        Ukraine  2016    Male            19.000
# 3           Chad  2008    Male            19.000
# 4           Chad  2004  Female            21.000
# ..           ...   ...     ...               ...
# 695      Lao PDR  2008    Male            61.000
# 696         Mali  2002    Male            61.000
# 697     Pakistan  2001    Male            61.000
# 698  South Sudan  2011  Female            61.000
# 699  Yemen, Rep.  2003    Male            61.000
#
# [700 rows x 4 columns]

# %%
plot_histogram(life_exep_data['HepB3 Immunization'], 'Count', 'HepB3 Immunization', "Histogram of HepB3 Immunization")

# %% [markdown]
# The data of HepB3 Immunization is skewed towards right.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['HepB3 Immunization'])
# Out:
# <Axes: xlabel='HepB3 Immunization'>

# %%
df = get_outlier(life_exep_data, 'HepB3 Immunization')
df[['Country','Year','Gender','HepB3 Immunization']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\700731301.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'HepB3 Immunization')
#                                           Country  Year  Gender  \
# 0                      Africa Western and Central  2000    Male
# 1                      Africa Western and Central  2000  Female
# 2    Least developed countries: UN classification  2000  Female
# 3    Least developed countries: UN classification  2000    Male
# 4                      Africa Western and Central  2001    Male
# ..                                            ...   ...     ...
# 669                                         India  2002  Female
# 670                                         India  2003  Female
# 671                                         India  2003    Male
# 672                                         India  2001    Male
# 673                                         India  2000    Male
#
#      HepB3 Immunization
# 0                 0.467
# 1                 0.467
# 2                 0.745
# 3                 0.745
# 4                 1.057
# ..                  ...
# 669              52.562
# 670              52.562
# 671              52.562
# 672              52.562
# 673              52.562
#
# [674 rows x 4 columns]

# %%
plot_histogram(life_exep_data['Measles Immunization'], 'Count', 'Measles Immunization', "Histogram of Measles Immunization")

# %% [markdown]
# The data of Measles Immunization is skewed towards right.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Measles Immunization'])
# Out:
# <Axes: xlabel='Measles Immunization'>

# %%
df = get_outlier(life_exep_data, 'Measles Immunization')
df[['Country','Year','Gender','Measles Immunization']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\2096827558.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Measles Immunization')
#                                     Country  Year  Gender  \
# 0                                      Chad  2004    Male
# 1                                      Chad  2004  Female
# 2                                   Somalia  2001    Male
# 3                                   Somalia  2001  Female
# 4                                    Angola  2006    Male
# ..                                      ...   ...     ...
# 451                             South Sudan  2005  Female
# 452  Heavily indebted poor countries (HIPC)  2000  Female
# 453  Heavily indebted poor countries (HIPC)  2000    Male
# 454  Heavily indebted poor countries (HIPC)  2001  Female
# 455  Heavily indebted poor countries (HIPC)  2001    Male
#
#      Measles Immunization
# 0                  16.000
# 1                  16.000
# 2                  20.000
# 3                  20.000
# 4                  21.000
# ..                    ...
# 451                54.111
# 452                54.326
# 453                54.326
# 454                54.738
# 455                54.738
#
# [456 rows x 4 columns]

# %%
plot_histogram(life_exep_data['Hospital beds'], 'Count', 'Hospital beds', "Histogram of Hospital beds")

# %% [markdown]
# The data of Hospital beds is skewed towards left.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Hospital beds'])
# Out:
# <Axes: xlabel='Hospital beds'>

# %%
df = get_outlier(life_exep_data, 'Hospital beds')
df[['Country','Year','Gender','Hospital beds']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\2648585740.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Hospital beds')
#        Country  Year  Gender  Hospital beds
# 0      Hungary  2010  Female          7.180
# 1    Lithuania  2009  Female          7.180
# 2    Lithuania  2008  Female          7.180
# 3      Hungary  2010    Male          7.180
# 4    Lithuania  2008    Male          7.180
# ..         ...   ...     ...            ...
# 511      Japan  2002  Female         14.430
# 512      Japan  2001    Male         14.580
# 513      Japan  2001  Female         14.580
# 514      Japan  2000  Female         14.690
# 515      Japan  2000    Male         14.690
#
# [516 rows x 4 columns]

# %%
plot_histogram(life_exep_data['Basic sanitation services'], 'Count', 'Basic sanitation services', "Histogram of Basic sanitation services")

# %% [markdown]
# From the above histogram we can find that the most of the data lies between 90 to 100.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Basic sanitation services'])
# Out:
# <Axes: xlabel='Basic sanitation services'>

# %%
df = get_outlier(life_exep_data, 'Basic sanitation services')
df[['Country','Year','Gender','Basic sanitation services']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\1200420017.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Basic sanitation services')
# Empty DataFrame
# Columns: [Country, Year, Gender, Basic sanitation services]
# Index: []

# %%
plot_histogram(life_exep_data['Tuberculosis treatment'], 'Count', 'Tuberculosis treatment', "Histogram of Tuberculosis treatment")

# %% [markdown]
# From the above histogram we can find that the most of the data of Tuberculosis treatment lies between 70 to 90.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Tuberculosis treatment'])
# Out:
# <Axes: xlabel='Tuberculosis treatment'>

# %%
df = get_outlier(life_exep_data, 'Tuberculosis treatment')
df[['Country','Year','Gender','Tuberculosis treatment']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\1199979087.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Tuberculosis treatment')
#       Country  Year  Gender  Tuberculosis treatment
# 0      Belize  2010    Male                   0.000
# 1      Greece  2007    Male                   0.000
# 2      Greece  2006    Male                   0.000
# 3      Greece  2005    Male                   0.000
# 4      Greece  2004    Male                   0.000
# ..        ...   ...     ...                     ...
# 491     Gabon  2016  Female                  48.000
# 492     Gabon  2011  Female                  48.000
# 493    Angola  2010  Female                  48.000
# 494      Oman  2019    Male                  48.000
# 495  Zimbabwe  2004    Male                  48.000
#
# [496 rows x 4 columns]

# %%
plot_histogram(life_exep_data['Urban population'], 'Count', 'Urban population', "Histogram of Urban population")

# %% [markdown]
# The above histogram shows that the data has comb distribution.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Urban population'])
# Out:
# <Axes: xlabel='Urban population'>

# %%
df = get_outlier(life_exep_data, 'Urban population')
df[['Country','Year','Gender','Urban population']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\3358090204.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Urban population')
# Empty DataFrame
# Columns: [Country, Year, Gender, Urban population]
# Index: []

# %%
plot_histogram(life_exep_data['Rural population'], 'Count', 'Rural population', "Histogram of Rural population")

# %% [markdown]
# Distribution of rural population is similar to urban population and has comb distribution.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Rural population'])
# Out:
# <Axes: xlabel='Rural population'>

# %%
df = get_outlier(life_exep_data, 'Rural population')
df[['Country','Year','Gender','Rural population']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\3460274049.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Rural population')
# Empty DataFrame
# Columns: [Country, Year, Gender, Rural population]
# Index: []

# %%
plot_histogram(life_exep_data['Non-communicable Mortality'], 'Count', 'Non-communicable Mortality', "Histogram of Non-communicable Mortality")

# %% [markdown]
# Non-communicable data is normally distributed and skewed towards left.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Non-communicable Mortality'])
# Out:
# <Axes: xlabel='Non-communicable Mortality'>

# %%
df = get_outlier(life_exep_data, 'Non-communicable Mortality')
df[['Country','Year','Gender','Non-communicable Mortality']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\3435372610.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Non-communicable Mortality')
#         Country  Year Gender  Non-communicable Mortality
# 0    Mozambique  2011   Male                      42.300
# 1          Fiji  2017   Male                      42.300
# 2    Kazakhstan  2009   Male                      42.400
# 3    Kazakhstan  2010   Male                      42.400
# 4       Lesotho  2003   Male                      42.400
# ..          ...   ...    ...                         ...
# 272    Kiribati  2004   Male                      62.600
# 273    Kiribati  2003   Male                      63.000
# 274    Kiribati  2002   Male                      63.600
# 275    Kiribati  2001   Male                      63.900
# 276    Kiribati  2000   Male                      64.100
#
# [277 rows x 4 columns]

# %%
plot_histogram(life_exep_data['Sucide Rate'], 'Count', 'Sucide Rate', "Histogram of Sucide Rate")

# %% [markdown]
# Sucide Rate data is kewed towards left.

# %%
sns.boxplot(data=life_exep_data, x=life_exep_data['Sucide Rate'])
# Out:
# <Axes: xlabel='Sucide Rate'>

# %% [markdown]
# Its seems that there are some outliers. Lets check them.

# %%
df = get_outlier(life_exep_data, 'Sucide Rate')
df[['Country','Year','Gender','Sucide Rate']]
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\2883602144.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   df = get_outlier(life_exep_data, 'Sucide Rate')
#          Country  Year Gender  Sucide Rate
# 0    Switzerland  2003   Male       24.400
# 1      Sri Lanka  2013   Male       24.400
# 2     Luxembourg  2001   Male       24.400
# 3        Croatia  2017   Male       24.400
# 4     Mozambique  2012   Male       24.400
# ..           ...   ...    ...          ...
# 703      Lesotho  2017   Male      127.200
# 704      Lesotho  2016   Male      139.600
# 705      Lesotho  2013   Male      139.900
# 706      Lesotho  2015   Male      147.300
# 707      Lesotho  2014   Male      147.800
#
# [708 rows x 4 columns]

# %% [markdown]
# From the above analysis we have found that there is serious issue of outlier on GDP and GNI. So, lets solve this issue by removing these data.

# %%
plt.figure(figsize = (10, 6))
ax = sns.boxplot(x='Gender', y='Life expectancy', data=life_exep_data)
plt.setp(ax.artists, alpha=.5, linewidth=2, edgecolor="k")
plt.xticks(rotation=45)
# Out:
# ([0, 1], [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %% [markdown]
# From the above boxplot, we can easily pridict that female has higher Life expectancy than male.

# %%
sns.set(rc={'figure.figsize':(10,10)})
sns.regplot(x="Life expectancy", y="Unemployment", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Unemployment'>

# %%
sns.regplot(x="Life expectancy", y="Infant Mortality", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Infant Mortality'>

# %%
sns.regplot(x="Life expectancy", y="GDP", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='GDP'>

# %%
sns.regplot(x="Life expectancy", y="GNI", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='GNI'>

# %%
sns.regplot(x="Life expectancy", y="Clean fuels and cooking technologies", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Clean fuels and cooking technologies'>

# %%
sns.regplot(x="Life expectancy", y="Per Capita", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Per Capita'>

# %%
sns.regplot(x="Life expectancy", y="Mortality caused by road traffic injury", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Mortality caused by road traffic injury'>

# %%
sns.regplot(x="Life expectancy", y="Tuberculosis Incidence", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Tuberculosis Incidence'>

# %%
sns.regplot(x="Life expectancy", y="DPT Immunization", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='DPT Immunization'>

# %%
sns.regplot(x="Life expectancy", y="HepB3 Immunization", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='HepB3 Immunization'>

# %%
sns.regplot(x="Life expectancy", y="Measles Immunization", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Measles Immunization'>

# %%
sns.regplot(x="Life expectancy", y="Hospital beds", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Hospital beds'>

# %%
sns.regplot(x="Life expectancy", y="Basic sanitation services", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Basic sanitation services'>

# %%
sns.regplot(x="Life expectancy", y="Tuberculosis treatment", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Tuberculosis treatment'>

# %%
sns.regplot(x="Life expectancy", y="Urban population", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Urban population'>

# %%
sns.regplot(x="Life expectancy", y="Rural population", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Rural population'>

# %%
sns.regplot(x="Life expectancy", y="Non-communicable Mortality", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Non-communicable Mortality'>

# %%
sns.regplot(x="Life expectancy", y="Sucide Rate", data=life_exep_data, scatter_kws={'s':1})
# Out:
# <Axes: xlabel='Life expectancy', ylabel='Sucide Rate'>

# %% [markdown]
# From the above corelation plot we can easily say that there are some multicollinearity issues between the variables. To solve this issue we are going to implement the PCA technique.

# %%
life_exep_data.head()
# Out:
#        Country  Year  Gender  Life expectancy  Unemployment  Infant Mortality  \
# 0  Afghanistan  2000  Female           57.120        13.846            85.000
# 1  Afghanistan  2001  Female           57.596        13.849            82.700
# 2  Afghanistan  2002  Female           58.080        14.355            80.400
# 3  Afghanistan  2003  Female           58.578        14.222            77.800
# 4  Afghanistan  2004  Female           59.093        14.047            75.300
#
#      GDP    GNI  Clean fuels and cooking technologies  Per Capita  ...  \
# 0 23.340 23.627                                 6.400     434.740  ...
# 1 23.340 23.627                                 7.200     434.740  ...
# 2 22.123 23.627                                 8.200     179.427  ...
# 3 22.231 23.627                                 9.400     190.684  ...
# 4 22.377 23.627                                10.400     211.382  ...
#
#    DPT Immunization  HepB3 Immunization  Measles Immunization  Hospital beds  \
# 0            24.000              65.077                27.000          0.300
# 1            33.000              65.077                37.000          0.390
# 2            36.000              65.077                35.000          0.390
# 3            41.000              65.077                39.000          0.390
# 4            50.000              65.077                48.000          0.390
#
#    Basic sanitation services  Tuberculosis treatment  Urban population  \
# 0                     21.871                  85.000            22.078
# 1                     21.881                  84.000            22.169
# 2                     23.274                  87.000            22.261
# 3                     24.667                  86.000            22.353
# 4                     26.068                  89.000            22.500
#
#    Rural population  Non-communicable Mortality  Sucide Rate
# 0            77.922                      39.400        4.800
# 1            77.831                      40.100        4.800
# 2            77.739                      40.500        4.600
# 3            77.647                      40.100        4.600
# 4            77.500                      40.200        4.600
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Standarize the data

# %% [markdown]
# We going to encode the Gender column because based on our research question we are going to predict the life expectancy base on the development indicators.

# %%
# Target variable
y = life_exep_data.iloc[:,3:4]

# Features
#X = life_exep_data.iloc[:, 2:]
X = life_exep_data.drop(['Country', 'Year', 'Life expectancy', 'Gender'], axis=1)

# %%
X
# Out:
#       Unemployment  Infant Mortality    GDP    GNI  \
# 0           13.846            85.000 23.340 23.627
# 1           13.849            82.700 23.340 23.627
# 2           14.355            80.400 22.123 23.627
# 3           14.222            77.800 22.231 23.627
# 4           14.047            75.300 22.377 23.627
# ...            ...               ...    ...    ...
# 9923         4.352            46.600 23.717 23.699
# 9924         4.358            45.100 23.746 23.727
# 9925         4.353            44.200 23.590 23.573
# 9926         4.360            42.900 23.620 23.603
# 9927         4.393            42.100 23.683 23.662
#
#       Clean fuels and cooking technologies  Per Capita  \
# 0                                    6.400     434.740
# 1                                    7.200     434.740
# 2                                    8.200     179.427
# 3                                    9.400     190.684
# 4                                   10.400     211.382
# ...                                    ...         ...
# 9923                                29.800    1445.070
# 9924                                29.700    1464.589
# 9925                                29.600    1235.189
# 9926                                29.800    1254.642
# 9927                                30.000    1316.741
#
#       Mortality caused by road traffic injury  Tuberculosis Incidence  \
# 0                                      14.700                 190.000
# 1                                      15.100                 189.000
# 2                                      14.900                 189.000
# 3                                      15.000                 189.000
# 4                                      15.200                 189.000
# ...                                       ...                     ...
# 9923                                   38.700                 242.000
# 9924                                   39.900                 233.000
# 9925                                   40.100                 221.000
# 9926                                   40.600                 210.000
# 9927                                   41.200                 199.000
#
#       DPT Immunization  HepB3 Immunization  Measles Immunization  \
# 0               24.000              65.077                27.000
# 1               33.000              65.077                37.000
# 2               36.000              65.077                35.000
# 3               41.000              65.077                39.000
# 4               50.000              65.077                48.000
# ...                ...                 ...                   ...
# 9923            87.000              87.000                86.000
# 9924            90.000              90.000                95.000
# 9925            89.000              89.000                90.000
# 9926            89.000              89.000                88.000
# 9927            90.000              90.000                85.000
#
#       Hospital beds  Basic sanitation services  Tuberculosis treatment  \
# 0             0.300                     21.871                  85.000
# 1             0.390                     21.881                  84.000
# 2             0.390                     23.274                  87.000
# 3             0.390                     24.667                  86.000
# 4             0.390                     26.068                  89.000
# ...             ...                        ...                     ...
# 9923          2.350                     38.121                  81.000
# 9924          2.350                     37.529                  81.000
# 9925          2.350                     36.942                  83.000
# 9926          2.350                     36.357                  84.000
# 9927          2.350                     35.774                  84.000
#
#       Urban population  Rural population  Non-communicable Mortality  \
# 0               22.078            77.922                      39.400
# 1               22.169            77.831                      40.100
# 2               22.261            77.739                      40.500
# 3               22.353            77.647                      40.100
# 4               22.500            77.500                      40.200
# ...                ...               ...                         ...
# 9923            32.385            67.615                      32.500
# 9924            32.296            67.704                      31.800
# 9925            32.237            67.763                      30.900
# 9926            32.209            67.791                      30.300
# 9927            32.210            67.790                      30.300
#
#       Sucide Rate
# 0           4.800
# 1           4.800
# 2           4.600
# 3           4.600
# 4           4.600
# ...           ...
# 9923       23.800
# 9924       22.500
# 9925       21.000
# 9926       19.900
# 9927       20.000
#
# [8448 rows x 18 columns]

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train
# Out:
#       Unemployment  Infant Mortality    GDP    GNI  \
# 1570         9.374             3.000 28.582 28.605
# 9617        10.360            11.700 25.524 25.466
# 8838         2.944             6.800 27.391 27.401
# 4869        16.674            20.200 22.358 22.423
# 7155         8.256            30.235 21.390 21.427
# ...            ...               ...    ...    ...
# 5133         7.778            14.700 26.531 26.500
# 9331         6.046             3.500 26.535 26.552
# 5619        11.398            18.300 21.191 21.154
# 3864        13.931            11.400 26.977 26.994
# 3252         2.945            22.200 24.255 24.265
#
#       Clean fuels and cooking technologies  Per Capita  \
# 1570                               100.000   38685.258
# 9617                                94.200    2639.392
# 8838                               100.000   23337.018
# 4869                                60.593    1543.701
# 7155                                60.593   24864.436
# ...                                    ...         ...
# 5133                                98.800    8225.138
# 9331                               100.000   37321.798
# 5619                                74.900    3043.031
# 3864                               100.000   20078.260
# 3252                                31.000    1194.957
#
#       Mortality caused by road traffic injury  Tuberculosis Incidence  \
# 1570                                    5.500                   9.000
# 9617                                   17.000                 115.000
# 8838                                   33.200                  10.000
# 4869                                    5.300                   0.980
# 7155                                   18.229                 136.043
# ...                                       ...                     ...
# 5133                                   13.300                  22.000
# 9331                                    6.000                   5.100
# 5619                                   25.000                  64.000
# 3864                                   25.700                  18.000
# 3252                                   16.300                 238.000
#
#       DPT Immunization  HepB3 Immunization  Measles Immunization  \
# 1570            96.000              90.000                90.000
# 9617            71.000              66.000                75.000
# 8838            96.000              97.000                98.000
# 4869            85.685              81.308                84.855
# 7155            85.685              81.308                84.855
# ...                ...                 ...                   ...
# 5133            94.000              94.000                96.000
# 9331            99.000              57.889                95.000
# 5619            93.000              94.000                92.000
# 3864            98.000              98.000                97.000
# 3252            93.000              93.000                92.000
#
#       Hospital beds  Basic sanitation services  Tuberculosis treatment  \
# 1570          5.980                     98.650                  24.000
# 9617          9.400                     96.102                  60.000
# 8838          2.296                    100.000                  90.000
# 4869          2.986                     91.466                 100.000
# 7155          2.986                     71.106                  76.726
# ...             ...                        ...                     ...
# 5133          4.610                     91.975                  43.000
# 9331          3.050                     98.991                  83.000
# 5619          2.100                     70.341                  89.000
# 3864          2.210                     99.045                  61.000
# 3252          1.413                     72.880                  89.000
#
#       Urban population  Rural population  Non-communicable Mortality  \
# 1570            80.180            19.820                       7.400
# 9617            68.502            31.498                      42.800
# 8838            83.844            16.156                      22.900
# 4869            73.061            26.939                      22.100
# 7155            51.851            48.149                      22.100
# ...                ...               ...                         ...
# 5133            90.691             9.309                      22.900
# 9331            84.196            15.804                      14.600
# 5619            64.300            35.700                      17.100
# 3864            81.649            18.351                      23.800
# 3252            20.153            79.847                      19.300
#
#       Sucide Rate
# 1570        8.000
# 9617       47.600
# 8838        9.100
# 4869       10.619
# 7155       10.619
# ...           ...
# 5133       13.900
# 9331       19.700
# 5619       24.000
# 3864        1.500
# 3252        2.700
#
# [5913 rows x 18 columns]

# %%
scaler = StandardScaler()
transformed_X_train = scaler.fit_transform(X_train)
transformed_X_test = scaler.transform(X_test)

# %%
pd.DataFrame(transformed_X_train).to_csv('data/impv/without_pca/X_train.csv', index=False, header=X_test.columns)
pd.DataFrame(transformed_X_test).to_csv('data/impv/without_pca/X_test.csv', index=False, header=X_test.columns)
y_train.to_csv('data/impv/without_pca/y_train.csv', index=False)
y_test.to_csv('data/impv/without_pca/y_test.csv', index=False)

# %%
pd.DataFrame(transformed_X_train, columns=X_train.columns).head(2)
# Out:
#    Unemployment  Infant Mortality   GDP   GNI  \
# 0         0.138            -1.046 1.932 1.909
# 1         0.289            -0.710 0.617 0.574
#
#    Clean fuels and cooking technologies  Per Capita  \
# 0                                 1.065       1.253
# 1                                 0.912      -0.517
#
#    Mortality caused by road traffic injury  Tuberculosis Incidence  \
# 0                                   -1.476                  -0.670
# 1                                   -0.136                  -0.116
#
#    DPT Immunization  HepB3 Immunization  Measles Immunization  Hospital beds  \
# 0             0.695               0.411                 0.347          1.268
# 1            -1.014              -0.976                -0.679          2.711
#
#    Basic sanitation services  Tuberculosis treatment  Urban population  \
# 0                      0.898                  -3.322             1.056
# 1                      0.814                  -1.040             0.557
#
#    Rural population  Non-communicable Mortality  Sucide Rate
# 0            -1.056                      -1.683       -0.229
# 1            -0.557                       2.302        3.182

# %% [markdown]
# Lets create PCA object from sklearn. And fit the standarised data to PCA. Here, we have use 80% and a threshold to reduct the dimension and noise.

# %%
# pca = PCA()
pca = PCA(n_components=0.9)
pca_data = pca.fit(transformed_X_train)
pca_data.explained_variance_ratio_
# Out:
# array([0.39246739, 0.12523992, 0.0909756 , 0.07474945, 0.06195232,
#        0.04960804, 0.04602064, 0.03452952, 0.0292097 ])

# %% [markdown]
# From the 80% threshold our 18 attributes has been reduced to 7 attributes. This will help use to improve the performance of algorithm significantly.
#
# Lets convert the variance ratio to percentage so that it will be easy to under stand the variance of each component.

# %%
np.cumsum(np.round(pca_data.explained_variance_ratio_, decimals = 4) * 100)
# Out:
# array([39.25, 51.77, 60.87, 68.34, 74.54, 79.5 , 84.1 , 87.55, 90.47])

# %% [markdown]
# Now lets visualise the weight of attribute on each component.

# %%
loadings = pca_data.components_

labels = ['PC' + str(x) for x in range(1, pca_data.n_components_+1)]

loadings_df = pd.DataFrame.from_dict(dict(zip(labels, loadings)))
loadings_df['variable'] = X_train.columns.values
loadings_df = loadings_df.set_index('variable')
loadings_df
# Out:
#                                            PC1    PC2    PC3    PC4    PC5  \
# variable
# Unemployment                             0.018 -0.157  0.244 -0.367  0.566
# Infant Mortality                        -0.333  0.142  0.059 -0.018  0.051
# GDP                                      0.191  0.419  0.074  0.432  0.135
# GNI                                      0.194  0.422  0.081  0.425  0.147
# Clean fuels and cooking technologies     0.333 -0.021  0.054 -0.085  0.015
# Per Capita                               0.213  0.166  0.063 -0.195 -0.280
# Mortality caused by road traffic injury -0.235  0.034  0.008  0.125  0.419
# Tuberculosis Incidence                  -0.217 -0.034  0.304  0.121  0.310
# DPT Immunization                         0.271 -0.344 -0.101  0.181  0.118
# HepB3 Immunization                       0.194 -0.391 -0.155  0.156  0.195
# Measles Immunization                     0.276 -0.327 -0.085  0.204  0.118
# Hospital beds                            0.204 -0.078  0.336  0.105 -0.267
# Basic sanitation services                0.333 -0.085  0.041 -0.106 -0.080
# Tuberculosis treatment                  -0.063 -0.133 -0.263  0.408  0.056
# Urban population                         0.290  0.185  0.134 -0.188  0.228
# Rural population                        -0.290 -0.185 -0.134  0.188 -0.228
# Non-communicable Mortality              -0.209 -0.250  0.403  0.141 -0.121
# Sucide Rate                              0.017 -0.177  0.634  0.210 -0.152
#
#                                            PC6    PC7    PC8    PC9
# variable
# Unemployment                             0.359  0.358  0.151 -0.198
# Infant Mortality                        -0.113 -0.115  0.002  0.043
# GDP                                     -0.004  0.198 -0.009 -0.151
# GNI                                      0.011  0.156  0.015 -0.136
# Clean fuels and cooking technologies     0.116  0.047 -0.121 -0.150
# Per Capita                              -0.306 -0.171  0.655 -0.111
# Mortality caused by road traffic injury -0.295 -0.241 -0.292  0.087
# Tuberculosis Incidence                  -0.173  0.131  0.537  0.326
# DPT Immunization                        -0.217  0.043  0.046 -0.073
# HepB3 Immunization                      -0.276 -0.069  0.031  0.111
# Measles Immunization                    -0.188  0.034  0.010 -0.038
# Hospital beds                            0.142  0.268 -0.145  0.726
# Basic sanitation services                0.163 -0.007  0.004 -0.124
# Tuberculosis treatment                   0.646 -0.387  0.338  0.102
# Urban population                         0.029 -0.429 -0.073  0.183
# Rural population                        -0.029  0.429  0.073 -0.183
# Non-communicable Mortality               0.094 -0.227 -0.085 -0.214
# Sucide Rate                             -0.038 -0.199 -0.051 -0.292

# %% [markdown]
# Lets visualise the weight on heatmap.

# %%
plt.figure(figsize=(15, 15))
ax = sns.heatmap(loadings_df, annot=True, cmap='Spectral')

# %% [markdown]
# Transform the data to proper format so that we can visualise the component on biplot.

# %%
weight_df = loadings_df.reset_index().iloc[:, :3]
weight_df = pd.melt(weight_df, id_vars="variable", var_name="Component", value_name="Weight")

# %%
sns.barplot(x='Component', y='Weight', hue='variable', data=weight_df, palette=sns.color_palette("Set2")).set_title("Weight plot of PC1 and PC2")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# C:\Users\Sakshi Kumari\AppData\Local\Temp\ipykernel_21008\2997400952.py:1: UserWarning:
# The palette list has fewer values (8) than needed (18) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x='Component', y='Weight', hue='variable', data=weight_df, palette=sns.color_palette("Set2")).set_title("Weight plot of PC1 and PC2")

# %% [markdown]
# Lets visualise the variance and component in scree plot.

# %%
pca_df = pd.DataFrame({'Explained variance':pca_data.explained_variance_ratio_,'Components':labels})
plt.figure(figsize=(15, 15))
sns.barplot(x='Components',y="Explained variance",  data=pca_df, color="c").set_title("PCA: variance plot")
# Out:
# Text(0.5, 1.0, 'PCA: variance plot')

# %%
plt.plot(np.cumsum(pca_data.explained_variance_ratio_))
plt.xlabel("Number of components")
plt.ylabel("Explained variance")
# Out:
# Text(0, 0.5, 'Explained variance')

# %%
# column_names = X_test.columns

# %%
# pd.DataFrame(column_names).to_csv('data/impv/columns.csv', index=False)

# %%
X_train = pca.transform(transformed_X_train)
X_test = pca.transform(transformed_X_test)

# %%
X_train.shape
# Out:
# (5913, 9)

# %% [markdown]
# With the help of Principal Component Analysisc (PCA) the feature has been reduced from 18 to 7. This will help to reduct the noise that is present in the dataset.

# %%
X_test.shape
# Out:
# (2535, 9)

# %%
y_train.shape
# Out:
# (5913, 1)

# %%
y_test.shape
# Out:
# (2535, 1)

# %%
pd.DataFrame(X_train).to_csv('data/impv/X_train.csv', index=False)
pd.DataFrame(X_test).to_csv('data/impv/X_test.csv', index=False)
y_train.to_csv('data/impv/y_train.csv', index=False)
y_test.to_csv('data/impv/y_test.csv', index=False)
